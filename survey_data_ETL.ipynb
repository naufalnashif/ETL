# %% [markdown]
# <a href="https://colab.research.google.com/github/naufalnashif/ETL/blob/main/survey_data_ETL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_excel('/content/Data - Survey Monkey Output Edited.xlsx', sheet_name="Edited_Data")
dataset.head()
# Out:
#    Respondent ID          Start Date            End Date  Email Address  \
# 0     5379192392 2021-01-22 12:01:17 2021-01-22 12:40:34            NaN
# 1     2658722536 2021-01-22 06:56:37 2021-01-22 07:34:10            NaN
# 2     4044163394 2021-01-22 06:35:18 2021-01-22 06:47:32            NaN
# 3     5535865599 2021-01-21 21:29:32 2021-01-21 21:40:24            NaN
# 4     3356802928 2021-01-21 17:26:39 2021-01-21 17:44:40            NaN
#
#    First Name  Last Name  Custom Data 1  \
# 0         NaN        NaN            NaN
# 1         NaN        NaN            NaN
# 2         NaN        NaN            NaN
# 3         NaN        NaN            NaN
# 4         NaN        NaN            NaN
#
#   Identify which division you work in. - Response  \
# 0                                  Infrastructure
# 1                                         Finance
# 2                                  Infrastructure
# 3                                  Infrastructure
# ...

# %%
dataset_modify = dataset.copy()
dataset_modify
# Out:
#      Respondent ID          Start Date            End Date  Email Address  \
# 0       5379192392 2021-01-22 12:01:17 2021-01-22 12:40:34            NaN
# 1       2658722536 2021-01-22 06:56:37 2021-01-22 07:34:10            NaN
# 2       4044163394 2021-01-22 06:35:18 2021-01-22 06:47:32            NaN
# 3       5535865599 2021-01-21 21:29:32 2021-01-21 21:40:24            NaN
# 4       3356802928 2021-01-21 17:26:39 2021-01-21 17:44:40            NaN
# ..             ...                 ...                 ...            ...
# 193     7940065082 2021-01-11 06:19:18 2021-01-11 06:32:59            NaN
# 194     5157705612 2021-01-11 06:19:14 2021-01-11 06:33:29            NaN
# 195     9920755555 2021-01-11 06:18:48 2021-01-11 06:27:27            NaN
# 196     6638341389 2021-01-11 06:19:01 2021-01-11 06:33:06            NaN
# 197     8114622230 2021-01-11 06:18:50 2021-01-11 06:26:46            NaN
#
#      First Name  Last Name  Custom Data 1  \
# ...

# %%
dataset_modify.columns
# Out:
# Index(['Respondent ID', 'Start Date', 'End Date', 'Email Address',
#        'First Name', 'Last Name', 'Custom Data 1',
#        'Identify which division you work in. - Response',
#        'Identify which division you work in. - Other (please specify)',
#        'Which of the following best describes your position level? - Response',
#        'Which generation are you apart of? - Response',
#        'Please select the gender in which you identify. - Response',
#        'Which duration range best aligns with your tenure at your company? - Response',
#        'Which of the following best describes your employment type? - Response',
#        'Question 1 - Response', 'Question 2 - Response',
#        'Question 3 - Open-Ended Response', 'Question 4 - Response',
#        'Question 4 - Other (please specify)', 'Question 5 - Response 1',
#        'Question 5 - Response 2', 'Question 5 - Response 3',
#        'Question 5 - Response 4', 'Question 5 - Response 5',
# ...

# %%
columns_to_drop = ['Start Date', 'End Date', 'Email Address', 'First Name', 'Last Name', 'Custom Data 1']

# %%
dataset_modify = dataset_modify.drop(columns = columns_to_drop)
dataset_modify
# Out:
#      Respondent ID Identify which division you work in. - Response  \
# 0       5379192392                                  Infrastructure
# 1       2658722536                                         Finance
# 2       4044163394                                  Infrastructure
# 3       5535865599                                  Infrastructure
# 4       3356802928                                 Port Operations
# ..             ...                                             ...
# 193     7940065082                                  Infrastructure
# 194     5157705612                                         Finance
# 195     9920755555                                 Port Operations
# 196     6638341389                                  Infrastructure
# 197     8114622230                          Information Technology
#
#     Identify which division you work in. - Other (please specify)  \
# 0                                                  NaN
# ...

# %%
id_vars = list(dataset_modify.columns)[:8]
value_vars = list(dataset_modify.columns)[8:]

# %%
dataset_melted = dataset_modify.melt(id_vars=id_vars, value_vars = value_vars, var_name='Question + Subquestion', value_name='Answer')
dataset_melted
# Out:
#        Respondent ID Identify which division you work in. - Response  \
# 0         5379192392                                  Infrastructure
# 1         2658722536                                         Finance
# 2         4044163394                                  Infrastructure
# 3         5535865599                                  Infrastructure
# 4         3356802928                                 Port Operations
# ...              ...                                             ...
# 17023     7940065082                                  Infrastructure
# 17024     5157705612                                         Finance
# 17025     9920755555                                 Port Operations
# 17026     6638341389                                  Infrastructure
# 17027     8114622230                          Information Technology
#
#       Identify which division you work in. - Other (please specify)  \
# 0                                                    NaN
# ...

# %%
questions_import = pd.read_excel('/content/Data - Survey Monkey Output Edited.xlsx', sheet_name = 'Question')
questions_import
# Out:
#      Raw Question Raw Subquestion       Question  Subquestion  \
# 0   Respondent ID             NaN  Respondent ID          NaN
# 1      Start Date             NaN     Start Date          NaN
# 2        End Date             NaN       End Date          NaN
# 3   Email Address             NaN  Email Address          NaN
# 4      First Name             NaN     First Name          NaN
# ..            ...             ...            ...          ...
# 95            NaN     Response 13    Question 29  Response 13
# 96            NaN     Response 14    Question 29  Response 14
# 97    Question 30      Response 1    Question 30   Response 1
# 98            NaN      Response 2    Question 30   Response 2
# 99            NaN      Response 3    Question 30   Response 3
#
#        Question + Subquestion
# 0               Respondent ID
# 1                  Start Date
# 2                    End Date
# 3               Email Address
# 4                  First Name
# ..                        ...
# ...

# %%
questions = questions_import.copy()
questions.drop(columns= ['Raw Question', 'Raw Subquestion', 'Subquestion'], inplace =True)
questions
# Out:
#          Question     Question + Subquestion
# 0   Respondent ID              Respondent ID
# 1      Start Date                 Start Date
# 2        End Date                   End Date
# 3   Email Address              Email Address
# 4      First Name                 First Name
# ..            ...                        ...
# 95    Question 29  Question 29 - Response 13
# 96    Question 29  Question 29 - Response 14
# 97    Question 30   Question 30 - Response 1
# 98    Question 30   Question 30 - Response 2
# 99    Question 30   Question 30 - Response 3
#
# [100 rows x 2 columns]

# %%
dataset_merged = pd.merge(left=dataset_melted, right=questions, how='left', left_on='Question + Subquestion', right_on='Question + Subquestion')
print("Original data", len(dataset_melted))
print("Merged data", len(dataset_merged))

dataset_merged
# Out:
# Original data 17028
# Merged data 17028
#        Respondent ID Identify which division you work in. - Response  \
# 0         5379192392                                  Infrastructure
# 1         2658722536                                         Finance
# 2         4044163394                                  Infrastructure
# 3         5535865599                                  Infrastructure
# 4         3356802928                                 Port Operations
# ...              ...                                             ...
# 17023     7940065082                                  Infrastructure
# 17024     5157705612                                         Finance
# 17025     9920755555                                 Port Operations
# 17026     6638341389                                  Infrastructure
# 17027     8114622230                          Information Technology
#
#       Identify which division you work in. - Other (please specify)  \
# ...

# %%
dataset_merged.groupby("Question")["Answer"].count().reset_index().sort_values('Answer', ascending = False)
# Out:
#        Question  Answer
# 21  Question 29    1584
# 17  Question 25     970
# 25   Question 5     676
# 26   Question 6     664
# 1   Question 10     585
# 16  Question 24     544
# 29   Question 9     453
# 28   Question 8     446
# 18  Question 26     436
# 23  Question 30     332
# 2   Question 11     239
# 27   Question 7     237
# 10  Question 19     226
# 24   Question 4     220
# 14  Question 22     214
# 19  Question 27     211
# 8   Question 17     135
# 13  Question 21     127
# 15  Question 23     120
# 20  Question 28     119
# 0    Question 1     119
# 11   Question 2     118
# 22   Question 3     117
# 7   Question 16     117
# 6   Question 15     114
# 3   Question 12     114
# 9   Question 18     109
# 4   Question 13     108
# 12  Question 20     105
# 5   Question 14     105

# %%
respondents = dataset_merged[dataset_merged['Answer'].notna()]
respondents = respondents.groupby("Question")["Respondent ID"].nunique().reset_index().sort_values("Respondent ID")
respondents.rename(columns = {'Respondent ID':'Respondents'}, inplace = True)
respondents
# Out:
#        Question  Respondents
# 5   Question 14          105
# 12  Question 20          105
# 4   Question 13          108
# 9   Question 18          109
# 3   Question 12          114
# 6   Question 15          114
# 22   Question 3          117
# 7   Question 16          117
# 11   Question 2          118
# 0    Question 1          119
# 20  Question 28          119
# 15  Question 23          120
# 13  Question 21          127
# 8   Question 17          135
# 19  Question 27          153
# 10  Question 19          157
# 14  Question 22          160
# 24   Question 4          161
# 27   Question 7          162
# 2   Question 11          164
# 23  Question 30          182
# 29   Question 9          188
# 28   Question 8          190
# 18  Question 26          193
# 25   Question 5          194
# 16  Question 24          195
# 26   Question 6          196
# 17  Question 25          198
# 21  Question 29          198
# 1   Question 10          198

# %%
dataset_merged_two = pd.merge(left=dataset_merged, right=respondents, how='left', left_on='Question', right_on='Question')
print("Original data", len(dataset_merged))
print("Merged data", len(dataset_merged_two))

dataset_merged_two
# Out:
# Original data 17028
# Merged data 17028
#        Respondent ID Identify which division you work in. - Response  \
# 0         5379192392                                  Infrastructure
# 1         2658722536                                         Finance
# 2         4044163394                                  Infrastructure
# 3         5535865599                                  Infrastructure
# 4         3356802928                                 Port Operations
# ...              ...                                             ...
# 17023     7940065082                                  Infrastructure
# 17024     5157705612                                         Finance
# 17025     9920755555                                 Port Operations
# 17026     6638341389                                  Infrastructure
# 17027     8114622230                          Information Technology
#
#       Identify which division you work in. - Other (please specify)  \
# ...

# %%
same_answer = dataset_merged #[dataset_merged['Answer'].notna()]
same_answer = same_answer.groupby(["Question + Subquestion", "Answer"])["Respondent ID"].nunique().reset_index()
same_answer.rename(columns = {'Respondent ID':'Same Answer'}, inplace = True)
same_answer
# Out:
#       Question + Subquestion    Answer  Same Answer
# 0      Question 1 - Response  Answer 1           14
# 1      Question 1 - Response  Answer 2           10
# 2      Question 1 - Response  Answer 3           13
# 3      Question 1 - Response  Answer 4           17
# 4      Question 1 - Response  Answer 5           22
# ..                       ...       ...          ...
# 683  Question 9 - Response 4  Answer 4           16
# 684  Question 9 - Response 4  Answer 5           13
# 685  Question 9 - Response 4  Answer 6           14
# 686  Question 9 - Response 4  Answer 7           12
# 687  Question 9 - Response 4  Answer 8           19
#
# [688 rows x 3 columns]

# %%
dataset_merged_three = pd.merge(left=dataset_merged_two, right=same_answer, how='left', left_on=['Question + Subquestion', 'Answer'], right_on=['Question + Subquestion', 'Answer'])
dataset_merged_three["Same Answer"].fillna(0, inplace = True)
print("Original data", len(dataset_merged_two))
print("Merged data", len(dataset_merged_three))

dataset_merged_three
# Out:
# Original data 17028
# Merged data 17028
#        Respondent ID Identify which division you work in. - Response  \
# 0         5379192392                                  Infrastructure
# 1         2658722536                                         Finance
# 2         4044163394                                  Infrastructure
# 3         5535865599                                  Infrastructure
# 4         3356802928                                 Port Operations
# ...              ...                                             ...
# 17023     7940065082                                  Infrastructure
# 17024     5157705612                                         Finance
# 17025     9920755555                                 Port Operations
# 17026     6638341389                                  Infrastructure
# 17027     8114622230                          Information Technology
#
#       Identify which division you work in. - Other (please specify)  \
# ...

# %%
output = dataset_merged_three.copy()

output.columns.values[1:8] = ['Division Primary', 'Division Secondary', 'Position', 'Generation', 'Gender', 'Tenure', 'Employment Type']
output

#Untuk mengubah nama kolom bisa juga dengan rename()
# output.rename(columns={'Identify which division you work in. - Response':'Division Primary',
#  'Identify which division you work in. - Other (please specify)':'Division Secondary',
#  'Which of the following best describes your position level? - Response':'Position',
#  'Which generation are you apart of? - Response':'Generation',
#  'Please select the gender in which you identify. - Response':'Gender',
#  'Which duration range best aligns with your tenure at your company? - Response':'Tenure',
#  'Which of the following best describes your employment type? - Response':'Employment Type'}, inplace = True)
# Out:
#        Respondent ID        Division Primary Division Secondary  \
# 0         5379192392          Infrastructure                NaN
# 1         2658722536                 Finance                NaN
# 2         4044163394          Infrastructure                NaN
# 3         5535865599          Infrastructure                NaN
# 4         3356802928         Port Operations                NaN
# ...              ...                     ...                ...
# 17023     7940065082          Infrastructure                NaN
# 17024     5157705612                 Finance                NaN
# 17025     9920755555         Port Operations                NaN
# 17026     6638341389          Infrastructure                NaN
# 17027     8114622230  Information Technology                NaN
#
#               Position                             Generation      Gender  \
# 0                Staff  Generation X (born between 1965-1980)        Male
# ...

# %%
output.to_excel('survey-monkey-final-output.xlsx', index=False)
